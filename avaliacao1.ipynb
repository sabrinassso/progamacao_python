# %% [markdown]
# <a href="https://colab.research.google.com/github/sabrinassso/progamacao_python/blob/main/avaliacao1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
1. O Reflorestador (Loop com Acumulador)
Em um mini-game de reflorestamento, o jogador deve plantar
 árvores até atingir uma meta de "Biomassa". Crie um programa
 que peça ao usuário a meta de biomassa (em unidades). Depois,
 use um while para ler sucessivamente o valor de biomassa de
 cada árvore plantada. O programa deve parar assim que a meta for
 atingida ou superada e exibir quantas árvores foram necessárias.
 '''

meta_biomassa = float(input('Digite a meta de Biomassa:'))
biomassa_atual = 0
total_arvores = 0

while biomassa_atual < meta_biomassa:
    biomassa_atual += float(input('Digite a biomassa da árvore plantada:'))
    total_arvores += 1

print('Meta atingida! Árvores: ', total_arvores, ' |total: ', biomassa_atual)
# Out:
# Digite a meta de Biomassa10
# Digite a biomassa da árvore plantada:5
# Digite a biomassa da árvore plantada:5
# Meta atingida! Árvores:  2  |total:  10.0

# %%
'''

. Se alguém chegar a 0, encerre e anuncie o vencedor.
'''

hp_heroi = 100
hp_monstro = 100

dano_heroi = int(input('Digite o dano do ataque do :'))
dano_monstro = int(input('Digite o dano do ataque do monstro:'))

while hp_heroi > 0 and hp_monstro > 0:
    hp_monstro -= dano_heroi
    hp_heroi -= dano_monstro
    print('HP Herói: ', max(hp_heroi, 0), ' |HP Monstro: ', max(hp_monstro, 0))

if hp_heroi <= 0 and  hp_monstro <= 0:
    print('Empate')

if hp_heroi <=0 and hp_monstro > 0:
    print('Monstro venceu!')

if hp_heroi > 0 and hp_monstro <= 0:
    print('Heroi venceu!')2. Simulador de Combate: Turnos de RPG
Em um jogo de turno, um herói tem 100 de HP e enfrenta um
monstro com 100 de HP. O programa deve pedir ao usuário o
dano do ataque do herói e o dano do ataque do monstro por
rodada. Use um while que continue enquanto ambos estiverem
com HP acima de zero. Ao final de cada turno, mostre o HP
restant de ambos
# Out:
# Digite o dano do ataque do heroi50
# Digite o dano do ataque do monstro30
# HP Herói:  70  |HP Monstro:  50
# HP Herói:  40  |HP Monstro:  0
# Heroi venceu!

# %%
'''
2. Simulador de Combate: Turnos de RPG
Em um jogo de turno, um herói tem 100 de HP e enfrenta um monstro com 100 de HP.
O programa deve pedir ao usuário o dano do ataque do herói e o dano do ataque do monstro por rodada.
Use um while que continue enquanto ambos estiverem com HP acima de zero. Ao final de cada turno,
mostre o HP restante de ambos. Se alguém chegar a 0, encerre e anuncie o vencedor.
. Se alguém chegar a 0, encerre e anuncie o vencedor.
'''

hp_heroi = 100
hp_monstro = 100

while hp_heroi > 0 and hp_monstro > 0:
    dano_heroi = int(input('Digite o dano do ataque do herói: '))
    dano_monstro = int(input('Digite o dano do ataque do monstro: '))

    hp_monstro -= dano_heroi
    hp_heroi -= dano_monstro

    print('HP Herói: ', max(hp_heroi, 0), ' | HP Monstro: ', max(hp_monstro, 0))


if hp_heroi <= 0 and hp_monstro <= 0:
    print('Empate! Ambos caíram.')

if hp_heroi <= 0 and hp_monstro > 0:
    print('O Monstro venceu!')

if hp_heroi > 0 and hp_monstro <= 0:
    print('O Herói venceu!')
# Out:
# Digite o dano do ataque do herói: 50
# Digite o dano do ataque do monstro: 30
# HP Herói:  70  | HP Monstro:  50
# Digite o dano do ataque do herói: 30
# Digite o dano do ataque do monstro: 20
# HP Herói:  50  | HP Monstro:  20
# Digite o dano do ataque do herói: 50
# Digite o dano do ataque do monstro: 20
# HP Herói:  30  | HP Monstro:  0
# O Herói venceu!

# %%
'''
3. Monitor de Inundação (Sentinela)
Você está desenvolvendo um sistema de alerta para uma Smart City.
O programa deve ler o nível do rio (em metros) continuamente.
* Se o nível for menor que 3m: "Estado Normal".
* Entre 3m e 5m: "Estado de Alerta".
* Acima de 5m: "Evacuação Imediata".
O programa só deve encerrar a leitura se o usuário digitar um
valor negativo (flag/bandeira de encerramento).
'''
nivel_rio = 0

while nivel_rio >=0:
  nivel_rio = float(input('Digite o nível do rio em metros, digite um valor negativo para sair:'))

  if nivel_rio < 0:
    print('Encerrando o programa')
    break

  if nivel_rio <= 3:
    print('Estado normal')

  if nivel_rio >= 3 and nivel <= 5:
    print('Estado de alerta')

  if nivel_rio > 5:
    print('Evacuação Imediata')
# Out:
# Digite o nível do rio em metros, digite um valor negativo para sair:0
# Estado normal
# Digite o nível do rio em metros, digite um valor negativo para sair:2
# Estado normal
# Digite o nível do rio em metros, digite um valor negativo para sair:3
# Estado normal
# Estado de alerta
# Digite o nível do rio em metros, digite um valor negativo para sair:4
# Estado de alerta
# Digite o nível do rio em metros, digite um valor negativo para sair:5
# Estado de alerta
# Digite o nível do rio em metros, digite um valor negativo para sair:6
# Estado de alerta
# Evacuação Imediata
# Digite o nível do rio em metros, digite um valor negativo para sair:-2
# Encerrando o programa

# %%
'''
4. O Coletor de Itens e Inventário
Em um jogo de exploração, o jogador tem uma mochila
com capacidade máxima de 15kg. Crie um programa que
peça o peso de cada item encontrado no cenário, um
por um. O while deve permitir a entrada de itens
enquanto o peso total não ultrapassar 15kg. Se um
item ultrapassar o limite, o programa deve avisar
"Mochila cheia, item descartado" e encerrar, mostrando o peso final total.
'''
peso_total = 0

while peso_total < 15:
  peso_item = float(input('Digite o peso do item encontrado:'))
  peso_total += peso_item

  if peso_total >= 15:
    print('Mochila cheia, item descartado')
    break
# Out:
# Digite o peso do item encontrado:5
# Digite o peso do item encontrado:5
# Digite o peso do item encontrado:5
# Mochila cheia, item descartado

# %%
'''
5. Média de Temperatura Global
Para um painel informativo sobre mudanças climáticas, você
precisa calcular a média de temperatura de um período. O
usuário deve informar quantos dias deseja analisar. Use o
while para ler a temperatura de cada um desses dias. Ao
final, o programa deve exibir a média aritmética das
temperaturas e informar se a média está "Acima do
esperado" (caso seja maior que 25°C) ou "Dentro da normalidade".
'''

dias = int(input('Digite quantos dias deseja analisar:'))
soma_temp = 0
cont      = 0

while cont < dias:
  temp = float(input('Digite a temperatura do dia:'))
  soma_temp += temp
  cont += 1

media = soma_temp / dias
print('Média de temperatura: ', media, 'ºC')

if media <= 25:
  print('Status = Dentro da normalidade')


if media > 25:
  print('Status: Acima do esperado')
# Out:
# Digite quantos dias deseja analisar:5
# Digite a temperatura do dia20
# Digite a temperatura do dia22
# Digite a temperatura do dia25
# Digite a temperatura do dia24
# Digite a temperatura do dia30
# Média de temperatura:  24.2 ºC
# Status = Dentro da normalidade
